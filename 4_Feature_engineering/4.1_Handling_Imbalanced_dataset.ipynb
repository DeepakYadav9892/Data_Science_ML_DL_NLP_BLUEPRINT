# %% [markdown]
# An imbalanced dataset is one where some classes have much fewer samples than others.
# Example:
#
# Fraud detection → 99% Normal, 1% Fraud
#
# Disease prediction → 95% Healthy, 5% Disease
#
# Why is it a problem?
#
# Model becomes biased toward majority class
#
# High accuracy, but poor recall for minority class
#
# Minority class (often important) is ignored
#
# Example:
# If model predicts “Normal” always → 99% accuracy but 0% fraud detected

# %% [markdown]
# Techniques to Handle Imbalanced Data
# 1. Resampling Techniques
# (a) Oversampling (Increase minority class)
#
# Duplicate or synthetically create minority samples
#
# Methods:
#
# Random Oversampling
#
# SMOTE (Synthetic Minority Oversampling Technique) ⭐
#
# Pros:
# ✔ No data loss
# Cons:
# ✘ Overfitting risk

# %% [markdown]
# (b) Undersampling (Reduce majority class)
#
# Remove samples from majority class
#
# Methods:
#
# Random Undersampling
#
# Tomek Links
#
# Pros:
# ✔ Faster training
# Cons:
# ✘ Loss of information

# %% [markdown]
# (c) Hybrid Sampling
#
# Combination of SMOTE + Undersampling

# %% [markdown]
# 2. Algorithm-Level Techniques
# (a) Class Weighting
#
# Give more importance to minority class
# Used in:
#
# Logistic Regression
#
# SVM
#
# Decision Trees
#
# Random Forest
#
# (b) Cost-Sensitive Learning
#
# Higher penalty for misclassifying minority class

# %% [markdown]
# 3. Use Proper Evaluation Metrics (Very Important)
#
# ❌ Accuracy (misleading)
# ✅ Better metrics:
#
# Precision
#
# Recall
#
# F1-score
#
# ROC-AUC
#
# Confusion Matrix

# %% [markdown]
# 4. Ensemble Techniques
#
# Random Forest (with class_weight)
#
# Gradient Boosting
#
# XGBoost / LightGBM (handles imbalance well)

# %% [markdown]
# 5. Data-Level Improvements
#
# Collect more minority data (best solution)
#
# Feature engineering
#
# Remove noise

# %% [markdown]
# An imbalanced dataset is one where class distribution is uneven.
# It causes biased models favoring the majority class.
# It can be handled using resampling techniques (oversampling, undersampling, SMOTE), algorithm-level methods (class weighting, cost-sensitive learning), ensemble methods, and by using proper evaluation metrics like precision, recall, F1-score instead of accuracy.

# %%
import numpy as np 
import pandas as pd 

#set the random seed for reproduciblity 

np.random.seed(123)

#create a dataframe with two classes 
n_samples=1000
class_0_ration=0.9
n_class_0=int(n_samples*class_0_ration)
n_class_1=n_samples-n_class_0

# %%
n_class_0,n_class_1
# Out:
# (900, 100)

# %%
#create my dataframe with imbalanced dataset 
class_0=pd.DataFrame({
    'feature_1':np.random.normal(loc=0,scale=1,size=n_class_0),
    'feature_2':np.random.normal(loc=0,scale=1,size=n_class_0),
    'target':[0]*n_class_0
})

class_1=pd.DataFrame({
    'feature_1':np.random.normal(loc=0,scale=1,size=n_class_1),
    'feature_2':np.random.normal(loc=0,scale=1,size=n_class_1),
    'target':[0]*n_class_1
})

# %%
df=pd.concat([class_0,class_1]).reset_index(drop=True)

# %%
df.head()
df.tail()
# Out:
#      feature_1  feature_2  target
# 995  -0.623629   0.845701       0
# 996   0.239810  -1.119923       0
# 997  -0.868240  -0.359297       0
# 998   0.902006  -1.609695       0
# 999   0.697490   0.013570       0

# %%
df['target'].value_counts()
# Out:
# target
# 0    1000
# Name: count, dtype: int64

# %%
##Upsampling 
df_minority=df[df['target']==1]
df_majority=df[df['target']==0]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 3
#       1 from sklearn.utils import resample
# ----> 3 df_minority_upsampled = resample(
#       4     df_minority,
#       5     replace=True,
#       6     n_samples=len(df_majority),
#       7     random_state=42
#       8 )
#
# File c:\DATA_SCIENCE_ML_NLP\dsvenv\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File c:\DATA_SCIENCE_ML_NLP\dsvenv\Lib\site-packages\sklearn\utils\_indexing.py:664, in resample(replace, n_samples, random_state, stratify, sample_weight, *arrays)
#     662     else:
#     663         p = None
# --> 664     indices = random_state.choice(
#     665         n_samples,
#     666         size=max_n_samples,
#     667         p=p,
#     668         replace=True,
#     669     )
#     670 else:
#     671     indices = np.arange(n_samples)
#
# File numpy/random/mtrand.pyx:969, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: a must be greater than 0 unless no samples are taken

# %%
print(df_minority.shape)
print(df_majority.shape)
# Out:
# (0, 3)
# (1000, 3)

# %%
df_minority = df[df['target'] == 1]   # but maybe class is 0/No/False

# %%
df_majority = df[df['target'] == 0]
df_minority = df[df['target'] == 1]

# %%
df_majority = df[df['target'] == 0]
df_minority = df[df['target'] == 1]

# %%
from sklearn.utils import resample

df_minority_upsampled = resample(
    df_minority,
    replace=True,
    n_samples=len(df_majority),
    random_state=42
)

df_balanced = pd.concat([df_majority, df_minority_upsampled])

print(df_balanced['target'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 3
#       1 from sklearn.utils import resample
# ----> 3 df_minority_upsampled = resample(
#       4     df_minority,
#       5     replace=True,
#       6     n_samples=len(df_majority),
#       7     random_state=42
#       8 )
#      10 df_balanced = pd.concat([df_majority, df_minority_upsampled])
#      12 print(df_balanced['target'].value_counts())
#
# File c:\DATA_SCIENCE_ML_NLP\dsvenv\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File c:\DATA_SCIENCE_ML_NLP\dsvenv\Lib\site-packages\sklearn\utils\_indexing.py:664, in resample(replace, n_samples, random_state, stratify, sample_weight, *arrays)
#     662     else:
#     663         p = None
# --> 664     indices = random_state.choice(
#     665         n_samples,
#     666         size=max_n_samples,
#     667         p=p,
#     668         replace=True,
#     669     )
#     670 else:
#     671     indices = np.arange(n_samples)
#
# File numpy/random/mtrand.pyx:969, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: a must be greater than 0 unless no samples are taken
