# %% [markdown]
# Statistics is the science of collecting, analyzing, and interpreting data to uncover patterns and make decisions. In data science, it acts as the backbone for understanding data and building reliable models.

# %% [markdown]
# from IPython.display import display, HTML
#
# display(HTML("<h2 style='color:red'>Statistics in Data science </h2>"))
# display(HTML("<p style='color:blue'>Statistics is the science of collecting, analyzing, and interpreting data to uncover patterns and make decisions. In data science, it acts as the backbone for understanding data and building reliable models.</p>"))
# display(HTML("<span style='color:green'>    Summarizes data using measures like mean, median, and variance
#     Models uncertainty with probability and distributions
#     Tests hypotheses (e.g., A/B testing)
#     Finds relationships through regression and correlation</span>"))

# %% [markdown]
# <h3 style="color:purple">Types of statistics
# 1.Descriptive Statistics
# 2.Inferential Statistics </h3>
# <p style="color:green">What is data in statistics ?
# 1.Qualitative Data .
# 2.Quantitative Data , Discreate data , Contineous data </p>

# %% [markdown]
# https://www.geeksforgeeks.org/data-science/statistics-for-data-science/
