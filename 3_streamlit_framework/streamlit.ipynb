# %% [markdown]
# Introduction to streamlit
#
# Streamlit is an opne sourcea pp faramework for machine learning adnd data science projects .it allows you to create beutiful web applications fo ryou machine learning and datascience projects with simple python scripts.
