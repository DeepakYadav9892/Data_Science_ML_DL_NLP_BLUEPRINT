# %% [markdown]
# Polymorphism
#
# Polymorphism is a core component in object oriented Programming that allows objects
# different classes to be treated as objcts of a common superclass. It provides a way to perform s single action in different forms.
#
# Polymorphism is typically achieved throough method overrinding and interfaces .

# %%
##method overiding 
##Method overiding allows a child class to provide a specific implementation of a method 
##that is already defined in its parent class

# %%
##Base class 
class Animal:
    def speak(self):
        return "Sound of the animal"
    ##Derived class 1 

class Dog(Animal):
    def speak(self):
        return "Woof!!!"
##Derived class 

class Cat(Animal):
    def speak(self):
        return "Meow!!!"
  ##fuction that demonnstrates polymorphism 
def animal_speak(animal):
    print(animal.speak())

dog=Dog()
cat=Cat()
print(dog.speak())
print(cat.speak())
# Out:
# Woof!!!
# Meow!!!

# %%
# Base class
class Shape:
    def area(self):
        return "The area of the figure"

# Derived class 1
class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

# Derived class 2
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius * self.radius

# Function that demonstrates polymorphism
def print_area(shape):
    print(f"The area is {shape.area()}")

rectangle = Rectangle(4, 5)
circle = Circle(3)

print_area(rectangle)
print_area(circle)
# Out:
# The area is 20
# The area is 28.259999999999998

# %% [markdown]
# ##Polymorphism with Abstract base classes
#
# Abstract base classes are used  to define common methods for group of related objects.objectThey can enforce that  derived class implement particual methods, promoting connsitency aacross diffrent implemntations.

# %%
from abc import ABC,abstractclassmethod
##Define an abstract class 
class Vehicle(ABC):
    @abstractclassmethod
    def start_engine(self):
        pass

    ##Derived class 1 

class Car(Vehicle):
    def start_engine(self):
        return "Car engineer started"
    
##Derived calss 2 
class Motorcycle(Vehicle):
    def start_vehicle(vehicle):
        print(vehicle.start_engine())
    ## Create objects of car and motorcycle 
    car=Car()
    morotcycle=Motorcycle()
    start_vehicle(car)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 15
#      12         return "Car engineer started"
#      14 ##Derived calss 2
# ---> 15 class Motorcycle(Vehicle):
#      16     def start_vehicle(vehicle):
#      17         print(vehicle.start_engine())
#
# Cell In[10], line 20, in Motorcycle()
#      18 ## Create objects of car and motorcycle
#      19 car=Car()
# ---> 20 morotcycle=Motorcycle()
#      21 start_vehicle(car)
#
# NameError: name 'Motorcycle' is not defined
