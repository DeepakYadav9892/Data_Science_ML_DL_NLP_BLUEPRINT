# %% [markdown]
# Class and objects :
#
# Object-Oriented Prgramming (oop) is progamming paradigm that uses 'Objects' to design applications and computer prgrams. Oop alows for modleing real world scenarios usiing classes and objects. this lesson covers the basics of creting classees and objects , including instannce variables and methods

# %%
##Class jis blue print for creating objects . attributes ,methods 
class Car:
    pass
audi=Car()
bmw=Car()

print(type(audi))
print(bmw)
# Out:
# <class '__main__.Car'>
# ...

# %%
##Instance variable and methods 
audi.windows=4
print(audi.windows)
# Out:
# 4

# %%
tata=Car()
tata.doors=4
print(tata.doors)
# Out:
# 4

# %%
##Instance variable and methods 
class Dog:
    ##constructor
    def __init__(self,name,age):
        self.name=name
        self.age=age

##Craetes objects 
dog1=Dog('seru',9)

# %%
print(dog1)

print(dog1.name)
dog1.age
# Out:
# ...
# seru
# 9

# %%
##Define class with instance methods 
class Dog:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def bark(self):
        print(f"{self.name} says woof ")

dog1=Dog("Buddy",4)
dog1.bark()
print(dog1)
# Out:
# Buddy says woof
# ...

# %%
###Modeling a Bank account 


##Deffine a class for bank accoutn 

class BankAccount:
    def __init__(self,owner,balance=0):
        self.owner=owner
        self.balance=balance
    def deposit(self,amount):
        self.balance+=amount
        print(f"{amount} is deposited .New balance is {self.balance}")

    def withdraw(self,amount):
        if amount>self.balance:
            print("Insufficent funds!")
        else:
            self.balance-=amount
            print(f"{amount} is withdrawn.new Balannce is {self.balance}")
    def get_balance(self):
        return self.balance
    
    ##create an account 
account=BankAccount("deepak",500)

# %%
print(account.balance)
account.deposit(1000)
# Out:
# 500
# 1000 is deposited .New balance is 1500
