# %% [markdown]
# Understanding the Simple Linear Regression Equation
#
# Simple Linear Regression is used to understand and model the relationship between one input variable (X) and one output variable (y) using a straight line.

# %% [markdown]
# 🔹 The Equation
#                y=mx+c
#
# This equation represents the best-fit straight line through the data.

# %% [markdown]
# y=β0​+β1​x

# %% [markdown]
# | Term       | Meaning                                  |
# | ---------- | ---------------------------------------- |
# | **y**      | Dependent variable (output / prediction) |
# | **x**      | Independent variable (input / feature)   |
# | **m / β₁** | Slope (weight)                           |
# | **c / β₀** | Intercept (bias)                         |

# %% [markdown]
# 2️⃣ Real-Life Example (Easy)
#
# 👉 House Price Prediction
#
# x = house size (sq ft)
#
# y = house price
#
# Equation:
#
# Price=m×Size+c
# Price=m×Size+c

# %% [markdown]
# 3️⃣ Slope (m) ka Detailed Meaning
#
# Slope batata hai:
#
# x me 1 unit change hone par y kitna change hoga
#
# Cases:

# %% [markdown]
# Cases:
#
# m > 0 → Positive relation 📈
#
# m < 0 → Negative relation 📉
#
# m = 0 → No relation (flat line)
#
# Example:
#
# m = 3 → x 1 badha ⇒ y 3 badha
#
# m = -2 → x 1 badha ⇒ y 2 kam

# %% [markdown]
# 4️⃣ Intercept (c) ka Meaning
#
# Intercept batata hai:
#
# jab x = 0 ho, tab y ki value kya hogi
#
# Example:
#
# y=4x+10
# y=4x+10

# %% [markdown]
# Jab x = 0
#
# y = 10
#
# 👉 Graph me ye Y-axis pe cut point hota hai.

# %% [markdown]
# 5️⃣ Graphical Understanding
#
# X-axis → Independent variable
#
# Y-axis → Dependent variable
#
# Line → Best fit line
#
# Best fit line wo hoti hai jo maximum points ke paas se guzarti hai.

# %% [markdown]
# 6️⃣ Why It’s Called “Regression”?
#
# Kyuki hum:
#
# Data points ke average behavior ko represent karte hain
#
# Extreme values se mean ki taraf regress karte hain

# %% [markdown]
# 7️⃣ Error / Residual Concept
#
# Actual value aur predicted value ke beech ka difference:
#
# Error=yactual−ypredicted
# Error=y
# actual
# 	​
#
# −y
# predicted
# 	​
#
#
# Goal hota hai:
#
# Total error ko minimum karna
#
# Iske liye hum use karte hain:
#
# Mean Squared Error (MSE)
