# %% [markdown]
# ##Polynomial Regression Implementation

# %%
import numpy as np 
import pandas as pd 
import  matplotlib.pyplot as plt 
# %matplotlib inline

# %%
X=6*np.random.rand(100,1)-3

y=0.5*X**2 + 1.5*X + 2+ np.random.randn(100,1)

##Qudratic eqauation used y=0.5

plt.plot(X,y,'g')

plt.xlabel('X dataset ')
plt.ylabel('Y dataset')
# Out:
# Text(0, 0.5, 'Y dataset')

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=)

# %%
##Lets implement Simple Linear Regressiion 
from sklearn.linear_model import LinearRegression
regression_1=LinearRegression()

# %%
poly=PolynomialFeatures(degree=2,include_bias=True)

X_train_poly=poly.fit_transfrom(X_train)

X_test_poly=poly.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 poly=PolynomialFeatures(degree=2,include_bias=True)
#       3 X_train_poly=poly.fit_transfrom(X_train)
#       5 X_test_poly=poly.transform(X_test)
#
# NameError: name 'PolynomialFeatures' is not defined
