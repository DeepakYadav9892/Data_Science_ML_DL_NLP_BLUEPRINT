# %% [markdown]
# ##Cost Function
# The cost function is one of the most important ideas in Machine Learning.
# It tells us how wrong our model’s predictions are.
#
# Cost Function = a numerical measure of total prediction error

# %% [markdown]
# 1️⃣ Why do we need a Cost Function?
#
# In Simple Linear Regression, our model is:
# y​=mx+c
#
# y → actual value
#
# ŷ → predicted value
#
# For every data point, the model makes some error:
#
# Error=y−y^
#
# The cost function combines all these errors into one single number so we can judge how good or bad the model is.

# %% [markdown]
# Cost Function used in Simple Linear Regression
#
# The most commonly used cost function is Mean Squared Error (MSE):
#
#
# ### Cost Function used in Simple Linear Regression
#
# The most commonly used cost function is **Mean Squared Error (MSE)**:
#
# $$
# J(m, c) = \frac{1}{n} \sum_{i=1}^{n} \left(y_i - (m x_i + c)\right)^2
# $$
#
# 	​

# %% [markdown]
# Meaning of each term

# %% [markdown]
# | Symb| Symbol      | Meaning               |
# | ----------- | --------------------- |
# | **J(m, c)** | Cost function value   |
# | **n**       | Number of data points |
# | **yᵢ**      | Actual output         |
# | **mxᵢ + c** | Predicted output      |
# | **( )²**    | Squared error         |
# ol      | Meaning               |
# | ----------- | --------------------- |
# | **J(m, c)** | Cost function value   |
# | **n**       | Number of data points |
# | **yᵢ**      | Actual output         |
# | **mxᵢ + c** | Predicted output      |
# | **( )²**    | Squared error         |

# %% [markdown]
# 4️⃣ Why do we square the errors? (Very Important)
#
# We square the errors because:
#
# Negative and positive errors don’t cancel each other
#
# Large errors get more penalty than small ones
#
# Squaring makes the function smooth and easy to optimize

# %% [markdown]
# Example:
#
# Error = −5 → Squared error = 25
#
# Error = 2 → Squared error = 4
#
# Big mistakes matter more.

# %% [markdown]
# 5️⃣ Simple Real-Life Example
#
# Suppose we predict marks based on study hours.
#
# | Hours (x) | Actual Marks (y) |
# | --------- | ---------------- |
# | 1         | 30               |
# | 2         | 40               |

# %% [markdown]
# 6.Graphical Intuition
# Vertical lines show errors (residuals)
#
# The cost function graph looks like a bowl (U-shape)
#
# The lowest point of the bowl = minimum cost
#
# This point gives the best values of m and c.

# %% [markdown]
# Goal of Training a Model
#
# The objective of training is simple:
#
# Minimize the cost function
#
# High cost → poor predictions ❌
#
# Low cost → accurate predictions ✅

# %% [markdown]
# 8️⃣ Connection with Gradient Descent
#
# To reduce the cost, we update parameters:
#
# m:=m−α∂J∂m
# m:=m−α
# ∂m
# ∂J
# 	​
#
# c:=c−α∂J∂c
# c:=c−α
# ∂c
# ∂J
# 	​
#
#
# α (learning rate) controls step size
#
# Each step moves us closer to the minimum cost

# %% [markdown]
# 9️⃣ Key Points for Exams & Interviews
#
# Cost function measures overall prediction error
#
# Mean Squared Error is used in linear regression
#
# Squaring errors penalizes large mistakes
#
# Minimizing cost = better model

# %% [markdown]
# 🔟 One-line Summary
#
# A cost function measures how far a model’s predictions are from actual values, and training aims to minimize this error.
