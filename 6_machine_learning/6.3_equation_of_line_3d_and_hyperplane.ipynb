# %% [markdown]
# Equation of Line, Plane (3D) and Hyperplane in Machine Learning
#
# In Machine Learning, these equations are used to:
#
# separate data (classification)
#
# fit relationships (regression)
#
# define decision boundaries
#
#
#
# (📌 Decision boundary banane ke liye
#
# 📌 Data separate karne ke liye
#
# 📌 Prediction aur classification ke liye)

# %% [markdown]
# 1️⃣ Equation of a Line (2D) – Foundation of ML
# 📐 Mathematical Form
#
# In 2D (x₁, x₂), the equation of a line is:
#
# w1x1+w2x2+b=0
#
# x1,x2 Input features
# w1,w2 Weights(features importance )
#
# b Bias(line ko upar -niche sift krta hai )
#
# OR (slope–intercept form):
#
# y=mx+c
# y=mx+c
#
# ML Example
#
# Spam detection:
#
# x₁ = Email length
#
# x₂ = Number of links
#
# ➡️ Line spam aur non-spam ko separate karti hai

# %% [markdown]
# Agar w₁x₁ + w₂x₂ + b ≥ 0 → Class 1
# Else → Class 0

# %% [markdown]
# 2️⃣ Equation of a Plane (3D)
# 🔹 Kab use hota hai?
#
# Jab 3 features hote hain, tab line nahi, plane banti hai.
#
# w1​x1​+w2​x2​+w3​x3​+b=0

# %% [markdown]
# | Component       | Explanation      |
# | --------------- | ---------------- |
# | (x_1, x_2, x_3) | 3 input features |
# | (w_1, w_2, w_3) | Weights          |
# | (b)             | Bias             |

# %% [markdown]
# ML Example
#
# Loan approval:
#
# x₁ = Income
#
# x₂ = Credit score
#
# x₃ = Age
#
# ➡️ Plane decide karti hai:
#
# Loan approved
#
# Loan rejected

# %% [markdown]
# 3️⃣ Hyperplane (Most Important in ML)
# 🔹 Simple definition
#
# Real ML problems me features bahut zyada hote hain (10, 100, 1000+).
# Is case me line ya plane nahi, balki hyperplane hoti hai.
#
#
# General Equation of Hyperplane

# %% [markdown]
# w1​x1​+w2​x2​+⋯+wn​xn​+b=0
#
# Short form:
#
# wTx+b=0
#
# 🔹 Terms ka matlab

# %% [markdown]
# | Term        | Meaning           |
# | ----------- | ----------------- |
# | (x_1 … x_n) | Multiple features |
# | (w_1 … w_n) | Feature weights   |
# | (b)         | Bias              |
# | Hyperplane  | Decision boundary |

# %% [markdown]
# 🔹 ML Algorithms jo Hyperplane use karte hain

# %% [markdown]
# | Algorithm           | Use                       |
# | ------------------- | ------------------------- |
# | Linear Regression   | Best fit hyperplane       |
# | Logistic Regression | Classification boundary   |
# | SVM                 | Maximum margin hyperplane |
# | Perceptron          | Linear separation         |
# | Neural Network      | Multiple hyperplanes      |

# %% [markdown]
# 4️⃣ Line vs Plane vs Hyperplane (Quick Table)
#
# | Dimensions | Boundary Type | Features |
# |----------|--------------|----------|
# | 2D | Line | 2 features |
# | 3D | Plane | 3 features |
# | nD | Hyperplane | n features |

# %% [markdown]
# 5️⃣ Distance from Hyperplane (SVM Concept)
#
# SVM me model try karta hai:
# 👉 Data points aur hyperplane ke beech maximum distance rakhna

# %% [markdown]
# Distance=∣∣w∣∣∣wTx+b∣​

# %% [markdown]
# Zyada distance = better confidence
#
# Isi ko margin bolte hain

# %% [markdown]
# 6️⃣ Easy Intuition (Exam Friendly)
#
# | Concept    | Easy Meaning                         |
# | ---------- | ------------------------------------ |
# | Line       | 2D data divide karti hai             |
# | Plane      | 3D data divide karti hai             |
# | Hyperplane | High-dimension data divide karti hai |
# | Weights    | Feature ki importance                |
# | Bias       | Boundary ko shift karta hai          |

# %% [markdown]
# One-Line Exam Answers
#
# Line → 2 features ke liye decision boundary
#
# Plane → 3 features ke liye decision boundary
#
# Hyperplane → n features ke liye decision boundary
#
# ML ka goal → best weights aur bias seekhna
