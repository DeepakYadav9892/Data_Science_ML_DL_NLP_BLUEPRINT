# %% [markdown]
# 📘 Distance of a Point from a Plane (Hinglish)
# 🔹 Plane ka general equation
#
# 3D space me plane ka equation hota hai:

# %% [markdown]
# Ax+By+Cz+D=0

# %% [markdown]
# 🔹 Point
#
# Maan lo ek point hai:
#
# P(x1,y1,z1)

# %% [markdown]
# Humein is point ka plane se shortest distance nikalna hai.

# %% [markdown]
# Distance Formula (MOST IMPORTANT)

# %% [markdown]
# $$
# \text{Distance} =
# \frac{|Ax_1 + By_1 + Cz_1 + D|}
# {\sqrt{A^2 + B^2 + C^2}}
# $$

# %% [markdown]
# Formula ka intuition (intuation in simple word )
# Numerator
#
# |Ax1 +By1+Cz1+D|

# %% [markdown]
# Point ko plane equation me put karte hain
#
# Absolute value isliye, kyunki distance negative nahi hota

# %% [markdown]
# Denominator:
# $$
# ||\vec{n}|| = \sqrt{A^2 + B^2 + C^2}
# $$

# %% [markdown]
# $$
# \text{Normal Vector} = (A, B, C)
# $$
#
# $$
# ||\vec{n}|| = \sqrt{A^2 + B^2 + C^2}
# $$

# %% [markdown]
# Matlab:
#
# 👉 Point se plane tak perpendicular (seedha) distance

# %% [markdown]
# Geometric Meaning
#
# Plane ke perpendicular direction me jo shortest line banti hai
#
# Us line ki length = distance of point from plane
