# %% [markdown]
# Exploratory Data Analysis (EDA)
#
# What is EDA?
#
# Exploratory Data Analysis (EDA) is the process of understanding your dataset before building any machine learning model.
#
# In simple words:
# EDA answers “What is inside my data?”
#
#
# Why is EDA important?
#
# Detect missing values
#
# Find outliers
#
# Understand data distribution
#
# Identify relationships between variables
#
# Prevent wrong assumptions before modeling

# %% [markdown]
# 1. Understand the structure
# df.head()
# df.info()
# df.shape
# df.isnull().sum() / 2. Check missing values
# df.describe()  /  3.Statistical summary ,Mean, median, min, max, std deviation

# %% [markdown]
# 4. Univariate Analysis (single column)
#
# Histogram → distribution
#
# Boxplot → outliers
#
# df["salary"].hist()

# %% [markdown]
# 5. Bivariate / Multivariate Analysis
#
# Relationship between variables
#
# sns.scatterplot(x="experience", y="salary", data=df)
# sns.boxplot(x="department", y="salary", data=df)
#
#
# Output of EDA
#
# ✔ You understand your data
# ✔ You know what problems exist
# ✔ You are ready for feature engineering

# %% [markdown]
# Feature Engineering
# What is Feature Engineering?
#
# Feature Engineering is the process of creating, modifying, or transforming features to improve model performance.
#
#
# In simple words:
# Feature Engineering answers “How can I make my data more useful for the model?”
#
#
#
#
# Why is Feature Engineering important?
#
# Directly impacts model accuracy
#
# Same algorithm + better features = better results
#
# Often more important than algorithm choice

# %%
import pandas as pd 

df=.pd.read_csv("winequality-red.csv")
df.head()
# Out:
#   Cell In[1], line 3
#     df=.pd.read_csv("winequality-red.csv")
#        ^
# SyntaxError: invalid syntax
